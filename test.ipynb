# %% [markdown]
# Here's me playing with COVID-19 data for Georgia.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#          date state dataQualityGrade   death  deathConfirmed  deathIncrease  \
# 0  2020-11-11    GA               A+  8806.0          8333.0             76
# 1  2020-11-10    GA               A+  8730.0          8264.0             53
# 2  2020-11-09    GA               A+  8677.0          8223.0             29
# 3  2020-11-08    GA               A+  8648.0          8194.0              1
# 4  2020-11-07    GA               A+  8647.0          8193.0             39
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0          473.0       32806.0                 32806.0                 2002.0
# 1          466.0       32631.0                 32631.0                 1938.0
# 2          454.0       32483.0                 32483.0                 1916.0
# 3          454.0       32468.0                 32468.0                 1846.0
# 4          454.0       32435.0                 32435.0                 1859.0
#
# ...

# %%
df = df_data_1.sort_values(by=['date'])

df.plot(x='date', y='hospitalizedCurrently')
